# %% [markdown]
# # Language modeling

# %% [markdown]
# Machine translation
#
# P(high winds tonite) > P(large winds tonite)

# %% [markdown]
# Spel correction
#
# P(about fifteen minutes from) > P(about fifteen minuets from)

# %% [markdown]
# Speech recognition
#
# P(I saw a van) >> P(eyes awe of an)

# %%
import librosa
import matplotlib.pyplot as plt

y, sr = librosa.load("speech-lab.m4a")

plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.show()
# Out:
# /tmp/ipykernel_22526/3325236077.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load("speech-lab.m4a")
# /home/malick/miniconda3/envs/pt/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
